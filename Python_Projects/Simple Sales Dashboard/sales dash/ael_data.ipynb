# %%
import pandas as pd
import numpy as np
import requests
from google.cloud import bigquery
import os
from google.oauth2 import service_account
import streamlit as st
from dotenv import load_dotenv
import pandas_gbq as pbgq

load_dotenv()

credentials = service_account.Credentials.from_service_account_file(
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"]
)
client = bigquery.Client(credentials=credentials)

# %%
data = pd.read_csv("ael_tax.csv")

# %%
df = pd.DataFrame(data)

# %%
df.drop_duplicates(subset=['Description'], inplace=True)

# %%
df = df.drop(index=12)

# %%
has_duplicates = df.duplicated().any()

# %%
pbgq.to_gbq(
    df,
    destination_table="depop.depop_data_raw",
    project_id="data-learning-490201",
    credentials=credentials,
    if_exists="replace",
)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 25890.77it/s]

# %%
df.columns
# Out:
# Index(['Date of sale', 'Time of sale', 'Date of listing', 'Bundle',
#        'Bundle - amount of items', 'Buyer', 'Brand', 'Description', 'Size',
#        'Item price', 'Buyer shipping cost', 'Total', 'USPS Cost', 'Depop fee',
#        'Depop Payments fee', 'Buyer Marketplace Fee', 'Boosting fee',
#        'Payment type', 'Estimated payout date', 'Payout arrival date',
#        'Category', 'Name', 'Address Line 1', 'Address Line 2', 'City', 'State',
#        'Post Code', 'Country', 'US Sales tax', 'Refunded to buyer amount',
#        'Fees refunded to seller'],
#       dtype='object')
